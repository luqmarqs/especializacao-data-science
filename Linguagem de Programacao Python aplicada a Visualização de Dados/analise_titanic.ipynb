# %%
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1YKV8Re6nGOIdXkbe6ixddeoJrWYZUhjg')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
df['Age'].plot(kind='hist', bins=30, title='Distribuição da Idade')
# Out:
# <Axes: title={'center': 'Distribuição da Idade'}, ylabel='Frequency'>

# %%
df['Age'].plot(kind='box', title='Boxplot da Idade')
# Out:
# <Axes: title={'center': 'Boxplot da Idade'}>

# %%
df['Sex'].value_counts().plot(kind='bar', title='Distribuição por Sexo')
# Out:
# <Axes: title={'center': 'Distribuição por Sexo'}, xlabel='Sex'>

# %%
df['Pclass'].value_counts().plot(kind='bar', title='Distribuição por Classe')
# Out:
# <Axes: title={'center': 'Distribuição por Classe'}, xlabel='Pclass'>

# %%
df['Survived'].value_counts().plot(kind='bar', title='Sobreviventes vs Não Sobreviventes')
# Out:
# <Axes: title={'center': 'Sobreviventes vs Não Sobreviventes'}, xlabel='Survived'>

# %%
df[df['Survived']==1]['Age'].plot(kind='hist', alpha=0.6, title='Idade dos sobreviventes')
# Out:
# <Axes: title={'center': 'Idade dos sobreviventes'}, ylabel='Frequency'>

# %%
df_titanic[df_titanic['Survived']==1]['Sex'].value_counts().plot(kind='bar', title='Gênero dos sobreviventes')
# Out:
# <Axes: title={'center': 'Gênero dos sobreviventes'}, xlabel='Sex'>

# %% [markdown]
# Insight: mulheres têm uma taxa de sobrevivência significativamente maior que homens, indicando prioridade durante o resgate.

# %%
df_titanic[df_titanic['Survived']==1]['Pclass'].value_counts().plot(kind='bar', title='Classe dos sobreviventes')
# Out:
# <Axes: title={'center': 'Classe dos sobreviventes'}, xlabel='Pclass'>

# %% [markdown]
# Passageiros da 1ª classe tiveram maior taxa de sobrevivência.
# Classe social influenciou a chance de escapar.
